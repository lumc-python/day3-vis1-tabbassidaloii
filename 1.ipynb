# %%
# %pylab inline
# Out:
# /home/tabbassidaloii/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# Populating the interactive namespace from numpy and matplotlib

# %%
from assignment import GC_percent 
import pandas as pd

# %%
gc_percent=GC_percent('data/records.fa')

# %%
hist(gc_percent.values())
title('GC Percent Distribution')
xlabel('GC %')
ylabel('count');

# %%
hist(gc_percent.values(), bins=20)
title('GC Percent Distribution')
xlabel('GC %')
ylabel('count');

# %%
hist(gc_percent.values(), bins=20, facecolor='teal', edgecolor='black', alpha=0.7)
title('GC Percent Distribution')
xlabel('GC %')
ylabel('count');
